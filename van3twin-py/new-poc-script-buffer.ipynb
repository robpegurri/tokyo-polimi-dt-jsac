# %% [markdown]
# # New Tokyo PoC Script

# %% [markdown]
# ## 1 · Scene & Environment Setup

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0" # Use GPU 0, will use CPU otherwise
import numpy as np
import pandas as pd
import json
import csv as _csv
import poc.setup as poc
import poc.utils as utils
import poc.rt as rt
import poc.topology as tp

path_suffix = "/home/polimi"

# Antennas are Car 1: [1, 2], RSU: [30, 31, 40], Car 2: [5, 6, 7]
transmitters = [30, 31, 5, 6]
receivers = [1, 2, 40, 7]

scene = poc.setup_scenario(
    file_name=f"{path_suffix}/tokyo-polimi-dt-jsac/scenarios/ookayama_full_flat/ookayama.xml",
    frequency=60e9,
    bandwidth=1000e6,
    verbose=False,
    time_checker=False
)

poc.setup_coordinate_systems(
    # Using the right corner of the porch of the main building (facing north) as reference point
    ref_sionna_x=162.396, ref_sionna_y=85.782, # Sionna RT
    ref_external_x=-13524.5, ref_external_y=-43817.64 # Tokyo Mobility DT
)

poc.setup_antenna_type(
    transmitters=transmitters,
    receivers=receivers,
    pattern="load_custom", # Use custom pattern defined by CSV files
    elevation_csv=f"{path_suffix}/tokyo-polimi-dt-jsac/panasonic-rsu-pattern/elevation_beam_16.csv",
    azimuth_csv=f"{path_suffix}/tokyo-polimi-dt-jsac/panasonic-rsu-pattern/azimuth_beam_16.csv",
    polarization="H", # Use horizontal (define how is mounted in setup_antenna_on_object)
    simulate_perfect_beamforming=True,
    use_look_at_ideal_pointing=False, # If False, use the custom point_toward_peer() function that considers the actual antenna orientation and heading, which is more realistic but may not achieve perfect alignment
    beam_sweeping_angle=60 # [-60, 60]
)

# Peers (Tx)->(Rx) are 30->1, 31->7, 6->40, 5->2
poc.setup_wireless_links(
    wireless_links=[(30, 1), (31, 7), (6, 40), (5, 2)] # (Tx, Rx)
)

poc.setup_rt(
    rt_max_depth=3,
    rt_los=True,
    rt_specular_reflection=True,
    rt_diffuse_reflection=True,
    rt_refraction=False,
    rt_diffraction=False,
    rt_corner_diffraction=False,
    rt_max_num_paths_per_src=1e5,
    rt_samples_per_src=1e5
)

poc.setup_filters(
    transmitters=transmitters,
    receivers=receivers,
    use_moving_average_filter=True,
    moving_average_window_size=5
)

struc = poc.startup(port=35944)
# Out:
#     [INFO] Loaded scene with frequency 60.0 GHz, bandwidth 1000.0 MHz.
#     [INFO] Expecting UDP messages from Tokyo Digital Twin on UDP/35944
#     [INFO] Setup procedure complete.

# %% [markdown]
# ## 2 · Object configurator

# %%
# ── Asset paths & TX powers ───────────────────────────────────────────────────
CAR_1_MESH       = f"{path_suffix}/tokyo-polimi-dt-jsac/obj_meshes/coms.ply"
CAR_2_MESH       = f"{path_suffix}/tokyo-polimi-dt-jsac/obj_meshes/estima.ply"
RSU_MESH         = f"{path_suffix}/tokyo-polimi-dt-jsac/obj_meshes/rsu.ply"
TREE_MESH        = f"{path_suffix}/tokyo-polimi-dt-jsac/obj_meshes/tree.ply"


# Add objects to the scene
poc.add_object(ref_obj_id=1, mesh_path=CAR_1_MESH, position=[193.263, 182.911, 0.758495])
poc.add_object(ref_obj_id=2, mesh_path=CAR_2_MESH, position=[213.124, 191.882, 0.874555])
poc.add_object(ref_obj_id=101, mesh_path=RSU_MESH, position=[192.407, 195.791, 5.0/2])

trees = {}
zt = 8.64/2
trees[1] = [189.811, 185.500, zt]
trees[2] = [190.055, 184.113, zt]
trees[3] = [189.510, 180.790, zt]
trees[4] = [188.870, 177.861, zt]
trees[5] = [188.285, 173.964, zt]
trees[6] = [188.032, 170.855, zt]
trees[7] = [187.597, 167.868, zt]
trees[8] = [187.121, 164.304, zt]
trees[9] = [186.578, 161.490, zt]
trees[10] = [185.993, 158.196, zt]
trees[11] = [185.631, 155.328, zt]
trees[12] = [185.161, 152.369, zt]

for i in range(1, len(trees) + 1):
    poc.add_tree(ref_tree_id=i, mesh_path=TREE_MESH, position=trees[i])

# Add antennas to each object
# Car 1 (Antennas: 1, 2)
poc.mount_antenna_on_object(ref_obj_id=1, 
                            ant_id=1, # peer=30 - V2I Client (Rx)
                            displacement=[-0.359, -0.048, 0.837505], orientation=[0, 0, 0], mounted_vertically=False)
poc.mount_antenna_on_object(ref_obj_id=1,  
                            ant_id=2, # peer=5 - V2V Client (Rx)
                            displacement=[0.719, -0.027, 0.319505], orientation=np.array([0, np.radians(-5), 0]), mounted_vertically=False)

# RSU (Antennas: 30, 31, 40)
poc.mount_antenna_on_object(ref_obj_id=101,
                            ant_id=30, # peer=1 - I2V Server (Tx)
                            displacement=[0, 0, 5.0/2 + 0.5], orientation=np.array([np.radians(220), np.radians(25), 0]), mounted_vertically=False,
                            tx_power_dbm=16)
poc.mount_antenna_on_object(ref_obj_id=101, 
                            ant_id=31, # peer=7 - I2V Server (Tx)
                            displacement=[0, 0, 5.0/2 + 0.5], orientation=np.array([np.radians(220), np.radians(25), 0]), mounted_vertically=False,
                            tx_power_dbm=16)
poc.mount_antenna_on_object(ref_obj_id=101, 
                            ant_id=40, # peer=6 - I2V Client (Rx)
                            displacement=[0, 0, 5.0/2 + 0.5], orientation=np.array([np.radians(-45), np.radians(25), 0]), mounted_vertically=False)

# Car 2 (Antennas: 5, 6, 7)
poc.mount_antenna_on_object(ref_obj_id=2, 
                            ant_id=5, #peer=2 - V2V Server (Tx)
                            displacement=[-1.024, -0.048, 1.071445], orientation=np.array([np.pi, np.radians(-10), 0]), mounted_vertically=False,
                            tx_power_dbm=16)
poc.mount_antenna_on_object(ref_obj_id=2, 
                            ant_id=6, # peer=40 - V2I Server (Tx)
                            displacement=[-0.431, -0.009, 1.071445], orientation=[np.pi, 0, 0], mounted_vertically=False,
                            tx_power_dbm=16)
poc.mount_antenna_on_object(ref_obj_id=2, 
                            ant_id=7, # peer=31 - V2I Client (Rx)
                            displacement=[-0.34, -0.037, 1.072445], orientation=np.array([0, np.radians(-10), 0]), mounted_vertically=False)
# Out:
#      [INFO] Found peer antenna for Rx 1 in wireless_links: its Tx is 30. Perfect beamforming simulation will be applied between these two antennas.
#      [INFO] Found peer antenna for Rx 2 in wireless_links: its Tx is 5. Perfect beamforming simulation will be applied between these two antennas.
#      [INFO] Found peer antenna for Tx 30 in wireless_links: its Rx is 1. Perfect beamforming simulation will be applied between these two antennas.
#      [INFO] Found peer antenna for Tx 31 in wireless_links: its Rx is 7. Perfect beamforming simulation will be applied between these two antennas.
#      [INFO] Found peer antenna for Rx 40 in wireless_links: its Tx is 6. Perfect beamforming simulation will be applied between these two antennas.
#      [INFO] Found peer antenna for Tx 5 in wireless_links: its Rx is 2. Perfect beamforming simulation will be applied between these two antennas.
#      [INFO] Found peer antenna for Tx 6 in wireless_links: its Rx is 40. Perfect beamforming simulation will be applied between these two antennas.
#      [INFO] Found peer antenna for Rx 7 in wireless_links: its Tx is 31. Perfect beamforming simulation will be applied between these two antennas.

# %% [markdown]
# ## 3 · Showtime!

# %%
import time
import json
import csv
import poc.rt as rt
import poc.utils as utils

udp_socket = struc["udp_socket"]
verbose = True
horizon = 1

def main():
    global horizon
    timestamp = None
    
    print("Starting main loop...")

    while True:

        # - - - - - - - - - - - - - - - - - - - - -

        # 1. RECEIVE AND PARSE MESSAGE FROM SOCKET

        # - - - - - - - - - - - - - - - - - - - - -

        # Drain socket buffer to keep only the latest message
        latest_payload = None
        latest_address = None
        udp_socket.setblocking(False)
        try:
            while True:
                payload, address = udp_socket.recvfrom(1024*10)
                latest_payload = payload
                latest_address = address
        except BlockingIOError:
            pass  # No more messages in buffer
        finally:
            udp_socket.setblocking(True)  # Return to blocking mode
        
        # If no message was received, wait for one
        if latest_payload is None:
            payload, address = udp_socket.recvfrom(1024*10)
            latest_payload = payload
            latest_address = address
        
        payload, address = latest_payload, latest_address
        struc["latest_msg_address"] = address
        message = payload.decode()

        print(f"\n  Received message from {address}")
        
        t_tot = time.time()
        # Parse the JSON message
        data = json.loads(message)

        # Check message type early and route accordingly
        if isinstance(data, dict) and "positions" in data and "links" in data:
            # Position/Link update message
            timestamp = data["time"]
            positions = data["positions"]
            links = data["links"]

        # Check if it is a configuration message 
        msg_entries = data.get("data") if isinstance(data.get("data"), list) else (data if isinstance(data, list) else [data])
        type_val = msg_entries[0].get("type") if msg_entries and isinstance(msg_entries[0], dict) else None

        # Apply RT_CONFIGURATION message
        if type_val and "RT_CONFIGURATION" in type_val.upper():
            utils.manage_online_reconfiguration(msg_entries, struc, is_manual_override=False)
            # Logs control message
            local_timestamp = time.time()
            with open(struc["log_file"], mode="a", newline="") as file:
                writer = csv.writer(file)
                writer.writerow([local_timestamp, timestamp, None,
                                message, None, None, None, None, None, None, None, None, None, None, None, None, None])

            continue

        # Apply CHANGE_PREDICTION_HORIZON message
        if type_val and "CHANGE_PREDICTION_HORIZON" in type_val.upper():
            horizon = float(msg_entries[0].get('value'))
            # Logs control message
            local_timestamp = time.time()
            with open(struc["log_file"], mode="a", newline="") as file:
                writer = csv.writer(file)
                writer.writerow([local_timestamp, timestamp, None,
                                message, None, None, None, None, None, None, None, None, None, None, None, None, None])
            
            continue


        if verbose:
            print(" ")
            print("  - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -  ")
            print(" ")



        
        # - - - - - - - - - - - - - - - - - - - - -

        # 2. EXTRACT MEASURED RSSIs FOR CALIBRATION

        # - - - - - - - - - - - - - - - - - - - - -

        if 'is_stale' in links["vehicle1.lower_sta__vehicle3.back_horizontal_ap"]:
            current_5vs2 = links["vehicle1.lower_sta__vehicle3.back_horizontal_ap"]["rssi_dbm"] if links["vehicle1.lower_sta__vehicle3.back_horizontal_ap"]["is_stale"] == False else None
            current_5vs2_log = current_5vs2
        else:
            print(" [WARN] Got no measurement for 5vs2")
            current_5vs2 = None
            current_5vs2_log = 0

        if 'is_stale' in links["rsu.south_relay__vehicle1.upper_sta"]:    
            current_30vs1 = links["rsu.south_relay__vehicle1.upper_sta"]["rssi_dbm"] if links["rsu.south_relay__vehicle1.upper_sta"]["is_stale"] == False else None
            current_30vs1_log = current_30vs1
        else:
            print(" [WARN] Got no measurement for 30vs1")
            current_30vs1 = None
            current_30vs1_log = 0

        if 'is_stale' in links["rsu.south_relay__vehicle3.front_upper_sta"]:
            current_31vs7 = links["rsu.south_relay__vehicle3.front_upper_sta"]["rssi_dbm"] if links["rsu.south_relay__vehicle3.front_upper_sta"]["is_stale"] == False else None
            current_31vs7_log = current_31vs7
        else:
            print(" [WARN] Got no measurement for 31vs7")
            current_31vs7 = None
            current_31vs7_log = 0

        if 'is_stale' in links["rsu.east_sta__vehicle3.back_upper_ap"]:    
            current_6vs40 = links["rsu.east_sta__vehicle3.back_upper_ap"]["rssi_dbm"] if links["rsu.east_sta__vehicle3.back_upper_ap"]["is_stale"] == False else None
            current_6vs40_log = current_6vs40
        else:
            print(" [WARN] Got no measurement for 6vs40")
            current_6vs40 = None
            current_6vs40_log = 0


        # - - - - - - - - - - - - - - - - - - - - -

        # 3. APPLY PREDICTED LOCATIONS IN SIONNA

        # - - - - - - - - - - - - - - - - - - - - -

        # Update the locations in the scenario
        t = time.time()

        for vehicle_id, trajectory in positions.items():
            for point in trajectory:
                dt = point['dt']
                if dt == horizon:
                    x = point['x']
                    y = point['y']
                    z = point['z'] 
                    yaw = -point['yaw'] + 90

                    if vehicle_id == '1':
                        # Update Car 1's position in Sionna
                        utils.move_object(ref_obj_id=1, 
                                            position=[x, z, 0.758495], 
                                            ref_system="external",
                                            heading_angle=yaw, 
                                            velocity=5,
                                            sionna_structure=struc)
                        print(f"    Updating Vehicle {vehicle_id} at dt={dt:.3f}s to position (x={x:.2f}, y={y:.2f}, z={z:.2f}) with yaw={yaw:.2f}°")
                    
                    elif vehicle_id == '3':
                        # Update Car 2's position in Sionna
                        utils.move_object(ref_obj_id=2, 
                                            position=[x, z, 0.975445], 
                                            ref_system="external",
                                            heading_angle=yaw, 
                                            velocity=5,
                                            sionna_structure=struc)
                        print(f"    Updating Vehicle {vehicle_id} at dt={dt:.3f}s to position (x={x:.2f}, y={y:.2f}, z={z:.2f}) with yaw={yaw:.2f}°")
        
        location_update_time = (time.time() - t) * 1000
        if struc["time_checker"]:
            print(f"        Location update took: {location_update_time:.2f} ms")



        # - - - - - - - - - - - - - - - - - - - - -

        # 4. COMPUTE FUTURE RSSI AND NET TOPOLOGY

        # - - - - - - - - - - - - - - - - - - - - -
       
        # Compute RSSIs
        t_c = time.time()
        raw_rssi_5vs2 = rt.compute_rssi(5, 2, struc)
        rssi_5vs2 = struc["filters"][('5', '2')].step(raw_rssi_5vs2, current_5vs2)
        los_5vs2 = rt.compute_los_status(5, 2, struc)
        can_bf_5vs2 = utils.can_beamform(5, 2, struc)

        print(f"    Raw RSSI 5vs2: {raw_rssi_5vs2:.2f} dBm, Filtered RSSI 5vs2: {rssi_5vs2:.2f} dBm (previous measurement was {current_5vs2_log} dBm) LOS: {los_5vs2}, Can BF: {can_bf_5vs2}")

        raw_rssi_6vs40 = rt.compute_rssi(6, 40, struc)
        rssi_6vs40 = struc["filters"][('6', '40')].step(raw_rssi_6vs40, current_6vs40)
        los_6vs40 = rt.compute_los_status(6, 40, struc)
        can_bf_6vs40 = utils.can_beamform(6, 40, struc)
        print(f"    Raw RSSI 6vs40: {raw_rssi_6vs40:.2f} dBm, Filtered RSSI 6vs40: {rssi_6vs40:.2f} dBm (previous measurement was {current_6vs40_log} dBm) LOS: {los_6vs40}, Can BF: {can_bf_6vs40}")

        raw_rssi_30vs1 = rt.compute_rssi(30, 1, struc)
        rssi_30vs1 = struc["filters"][('30', '1')].step(raw_rssi_30vs1, current_30vs1)
        los_30vs1 = rt.compute_los_status(30, 1, struc)
        can_bf_30vs1 = utils.can_beamform(30, 1, struc)
        print(f"    Raw RSSI 30vs1: {raw_rssi_30vs1:.2f} dBm, Filtered RSSI 30vs1: {rssi_30vs1:.2f} dBm (previous measurement was {current_30vs1_log} dBm) LOS: {los_30vs1}, Can BF: {can_bf_30vs1}")

        raw_rssi_31vs7 = rt.compute_rssi(31, 7, struc)
        rssi_31vs7 = struc["filters"][('31', '7')].step(raw_rssi_31vs7, current_31vs7)
        los_31vs7 = rt.compute_los_status(31, 7, struc)
        can_bf_31vs7 = utils.can_beamform(31, 7, struc)
        print(f"    Raw RSSI 31vs7: {raw_rssi_31vs7:.2f} dBm, Filtered RSSI 31vs7: {rssi_31vs7:.2f} dBm (previous measurement was {current_31vs7_log} dBm) LOS: {los_31vs7}, Can BF: {can_bf_31vs7}")

        # Compute topology (change the margin if necessary)
        topology = tp.evaluate_best_topology(sionna_structure=struc, margin_dbm=5,
                                             rssi_5vs2=rssi_5vs2, 
                                             rssi_6vs40=rssi_6vs40, 
                                             rssi_30vs1=rssi_30vs1, 
                                             rssi_31vs7=rssi_31vs7)
        
        print(f"    - - - Predicted Topology for original timestamp {timestamp} plus horizon {horizon}s - - - ")
        print(f"    ->  Predicted Topology_Vehicle2_1: {topology['Topology_Vehicle2_1']['Suggested_Topology']} ({topology['Topology_Vehicle2_1']['Type']})")
        print(f"    ->  Predicted Topology_RSU_Vehicle1: {topology['Topology_RSU_Vehicle1']['Suggested_Topology']} ({topology['Topology_RSU_Vehicle1']['Type']})")

        prediction_time = (time.time() - t_c) * 1000
        if struc["time_checker"]:
            print(f"        RT and Topology Prediction took: {prediction_time:.2f} ms")



        # - - - - - - - - - - - - - - - - - - - - -

        # 5. SEND BACK FUTURE NETWORK TOPOLOGY

        # - - - - - - - - - - - - - - - - - - - - -

        # Prepare the response
        response = [{}]
        response[0]["horizon"] = horizon
        response[0]["request_time"] = timestamp
        response[0]["data"] = {}
        response[0]["data"]["topology"] = topology

        response = json.dumps(response, default=lambda o: float(o) if isinstance(o, np.float32) else o)

        # Send back the response
        udp_socket.sendto(response.encode(), ("11.0.0.1", 5560))
        #udp_socket.sendto(response.encode(), address) # Use this for local testing script
        total_elapsed_time = (time.time() - t_tot) * 1000

        if verbose:
            print(" ")
            print(f"  - - - - - - - - - - - - - - - - -   Handled in {total_elapsed_time:.2f} ms   - - - - - - - - - - - - - - - - -  ")
            print(" ")
            print(" ")
        
        # Logging
        local_unix_timestamp = time.time()
        with open(struc["log_file"], mode="a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([local_unix_timestamp, timestamp, horizon,
                             message, response,
                             struc["sionna_location_db"][1]['x'], struc["sionna_location_db"][1]['y'], struc["sionna_location_db"][1]['angle'],
                             struc["sionna_location_db"][2]['x'], struc["sionna_location_db"][2]['y'], struc["sionna_location_db"][2]['angle'],
                             raw_rssi_5vs2, raw_rssi_6vs40, raw_rssi_30vs1, raw_rssi_31vs7,
                             rssi_5vs2, rssi_6vs40, rssi_30vs1, rssi_31vs7,
                             los_5vs2, los_6vs40, los_30vs1, los_31vs7,
                             can_bf_5vs2, can_bf_6vs40, can_bf_30vs1, can_bf_31vs7,
                             location_update_time, prediction_time, total_elapsed_time])
        
        '''
        from sionna.rt import render_to_file
        # Frame-by-frame exporter
        global frame_num
        print("Exporting frame ", frame_num)
        
        struc["scene"].render_to_file(camera=my_cam, 
                                         filename=f"/home/rpegurri/Tokyo NDT Integration/PoC Tokyo Science/export/frame_{frame_num}.png", 
                                         show_devices=False)
        frame_num += 1
        '''
        

        if message.startswith("SHUTDOWN_SIONNA"):
            print("Got SHUTDOWN_SIONNA message. Bye!")
            udp_socket.close()
            break

# Entry point
if __name__ == "__main__":
    main()
# Out:
# Starting main loop...
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13481.13, y=70.00, z=-43714.53) with yaw=109.67°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13466.46, y=70.00, z=-43718.23) with yaw=106.98°
#     Raw RSSI 5vs2: -32.37 dBm, Filtered RSSI 5vs2: -41.18 dBm (previous measurement was -50.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -47.90 dBm, Filtered RSSI 6vs40: -52.95 dBm (previous measurement was -58.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -156.38 dBm, Filtered RSSI 30vs1: -112.19 dBm (previous measurement was -68.0 dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -121.11 dBm, Filtered RSSI 31vs7: -121.11 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 248.848098754 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 1050.46 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13475.03, y=70.00, z=-43715.82) with yaw=108.75°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13462.20, y=70.00, z=-43719.25) with yaw=105.37°
#     Raw RSSI 5vs2: -31.21 dBm, Filtered RSSI 5vs2: -43.40 dBm (previous measurement was -49.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -37.10 dBm, Filtered RSSI 6vs40: -50.70 dBm (previous measurement was -57.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -169.82 dBm, Filtered RSSI 30vs1: -101.94 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -116.89 dBm, Filtered RSSI 31vs7: -116.89 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 251.350982666 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 632.98 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13473.69, y=70.00, z=-43716.10) with yaw=109.33°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13461.70, y=70.00, z=-43719.38) with yaw=105.84°
#     Raw RSSI 5vs2: -39.05 dBm, Filtered RSSI 5vs2: -46.51 dBm (previous measurement was -48.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -35.28 dBm, Filtered RSSI 6vs40: -51.82 dBm (previous measurement was -57.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -168.08 dBm, Filtered RSSI 30vs1: -93.02 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -116.70 dBm, Filtered RSSI 31vs7: -116.70 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 251.974060058 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 634.31 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13471.32, y=70.00, z=-43716.66) with yaw=110.10°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13460.55, y=70.00, z=-43719.68) with yaw=105.19°
#     Raw RSSI 5vs2: -38.00 dBm, Filtered RSSI 5vs2: -46.20 dBm (previous measurement was -46.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -35.57 dBm, Filtered RSSI 6vs40: -53.31 dBm (previous measurement was -59.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -166.03 dBm, Filtered RSSI 30vs1: -87.61 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -111.34 dBm, Filtered RSSI 31vs7: -111.34 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 252.726745605 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 643.59 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13469.90, y=70.00, z=-43716.98) with yaw=110.46°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13459.85, y=70.00, z=-43719.88) with yaw=106.42°
#     Raw RSSI 5vs2: -37.32 dBm, Filtered RSSI 5vs2: -45.89 dBm (previous measurement was -45.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -35.75 dBm, Filtered RSSI 6vs40: -54.46 dBm (previous measurement was -60.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -166.57 dBm, Filtered RSSI 30vs1: -84.43 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -112.08 dBm, Filtered RSSI 31vs7: -112.08 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 253.035507202 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 627.27 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13468.54, y=70.00, z=-43717.32) with yaw=110.62°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13459.13, y=70.00, z=-43720.14) with yaw=109.39°
#     Raw RSSI 5vs2: -31.17 dBm, Filtered RSSI 5vs2: -44.19 dBm (previous measurement was -46.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -34.33 dBm, Filtered RSSI 6vs40: -54.22 dBm (previous measurement was -58.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -167.24 dBm, Filtered RSSI 30vs1: -84.54 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -149.65 dBm, Filtered RSSI 31vs7: -149.65 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 253.940155029 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 546.11 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13467.52, y=70.00, z=-43717.56) with yaw=110.97°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13458.60, y=70.00, z=-43720.37) with yaw=111.78°
#     Raw RSSI 5vs2: -30.65 dBm, Filtered RSSI 5vs2: -43.61 dBm (previous measurement was -46.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -33.14 dBm, Filtered RSSI 6vs40: -54.52 dBm (previous measurement was -60.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -168.50 dBm, Filtered RSSI 30vs1: -84.75 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -164.08 dBm, Filtered RSSI 31vs7: -164.08 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 254.420242309 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 612.23 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13465.92, y=70.00, z=-43717.94) with yaw=111.17°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13457.77, y=70.00, z=-43720.73) with yaw=115.57°
#     Raw RSSI 5vs2: -26.19 dBm, Filtered RSSI 5vs2: -42.70 dBm (previous measurement was -47.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -34.66 dBm, Filtered RSSI 6vs40: -55.28 dBm (previous measurement was -60.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -169.26 dBm, Filtered RSSI 30vs1: -84.88 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -168.26 dBm, Filtered RSSI 31vs7: -168.26 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 255.064224243 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 600.29 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13465.05, y=70.00, z=-43718.11) with yaw=111.50°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13457.09, y=70.00, z=-43721.04) with yaw=118.71°
#     Raw RSSI 5vs2: -29.52 dBm, Filtered RSSI 5vs2: -43.25 dBm (previous measurement was -46.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -38.30 dBm, Filtered RSSI 6vs40: -56.05 dBm (previous measurement was -60.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -170.33 dBm, Filtered RSSI 30vs1: -85.05 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -126.26 dBm, Filtered RSSI 31vs7: -126.26 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 255.459014892 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 597.35 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13463.97, y=70.00, z=-43718.40) with yaw=111.81°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13456.71, y=70.00, z=-43721.20) with yaw=120.36°
#     Raw RSSI 5vs2: -25.04 dBm, Filtered RSSI 5vs2: -42.17 dBm (previous measurement was -43.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -44.45 dBm, Filtered RSSI 6vs40: -57.08 dBm (previous measurement was -60.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -171.41 dBm, Filtered RSSI 30vs1: -85.24 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -125.37 dBm, Filtered RSSI 31vs7: -125.37 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 256.347717285 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 603.32 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13463.13, y=70.00, z=-43718.65) with yaw=111.96°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13456.23, y=70.00, z=-43721.43) with yaw=122.69°
#     Raw RSSI 5vs2: -24.55 dBm, Filtered RSSI 5vs2: -41.26 dBm (previous measurement was -41.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -41.05 dBm, Filtered RSSI 6vs40: -57.34 dBm (previous measurement was -63.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -171.76 dBm, Filtered RSSI 30vs1: -85.29 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -124.42 dBm, Filtered RSSI 31vs7: -124.42 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 256.819793701 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 596.05 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13462.38, y=70.00, z=-43718.83) with yaw=112.19°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13456.03, y=70.00, z=-43721.51) with yaw=122.66°
#     Raw RSSI 5vs2: -23.69 dBm, Filtered RSSI 5vs2: -40.61 dBm (previous measurement was -43.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -41.10 dBm, Filtered RSSI 6vs40: -57.85 dBm (previous measurement was -63.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -172.54 dBm, Filtered RSSI 30vs1: -85.42 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -124.41 dBm, Filtered RSSI 31vs7: -124.41 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 257.44631958 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 525.51 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13461.65, y=70.00, z=-43719.07) with yaw=112.36°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13455.73, y=70.00, z=-43721.68) with yaw=124.00°
#     Raw RSSI 5vs2: -26.53 dBm, Filtered RSSI 5vs2: -40.09 dBm (previous measurement was -41.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -50.65 dBm, Filtered RSSI 6vs40: -59.94 dBm (previous measurement was -63.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -172.04 dBm, Filtered RSSI 30vs1: -85.34 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -124.09 dBm, Filtered RSSI 31vs7: -124.09 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 257.96194458 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 605.25 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13461.21, y=70.00, z=-43719.21) with yaw=111.90°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13455.11, y=70.00, z=-43722.03) with yaw=127.10°
#     Raw RSSI 5vs2: -23.26 dBm, Filtered RSSI 5vs2: -38.71 dBm (previous measurement was -41.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -92.33 dBm, Filtered RSSI 6vs40: -67.39 dBm (previous measurement was -63.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -171.15 dBm, Filtered RSSI 30vs1: -85.19 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -124.21 dBm, Filtered RSSI 31vs7: -124.21 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 258.610473632 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 599.72 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13460.83, y=70.00, z=-43719.32) with yaw=111.69°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13454.49, y=70.00, z=-43722.45) with yaw=130.06°
#     Raw RSSI 5vs2: -27.40 dBm, Filtered RSSI 5vs2: -38.73 dBm (previous measurement was -39.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -51.02 dBm, Filtered RSSI 6vs40: -61.00 dBm (previous measurement was -63.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -170.37 dBm, Filtered RSSI 30vs1: -85.06 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -125.55 dBm, Filtered RSSI 31vs7: -125.55 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 258.956329345 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 540.10 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13460.53, y=70.00, z=-43719.39) with yaw=111.74°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13453.86, y=70.00, z=-43722.92) with yaw=132.92°
#     Raw RSSI 5vs2: -24.65 dBm, Filtered RSSI 5vs2: -38.27 dBm (previous measurement was -41.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -66.89 dBm, Filtered RSSI 6vs40: -62.82 dBm (previous measurement was -58.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -170.41 dBm, Filtered RSSI 30vs1: -85.07 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -127.48 dBm, Filtered RSSI 31vs7: -127.48 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 259.515228271 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 543.95 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13460.16, y=70.00, z=-43719.50) with yaw=111.91°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13452.87, y=70.00, z=-43724.01) with yaw=141.03°
#     Raw RSSI 5vs2: -36.08 dBm, Filtered RSSI 5vs2: -39.85 dBm (previous measurement was -41.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -67.30 dBm, Filtered RSSI 6vs40: -62.38 dBm (previous measurement was -60.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 30vs1: -170.73 dBm, Filtered RSSI 30vs1: -85.12 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -166.32 dBm, Filtered RSSI 31vs7: -166.32 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 260.346069335 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 524.51 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13459.31, y=70.00, z=-43719.71) with yaw=114.55°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13452.03, y=70.00, z=-43724.86) with yaw=145.18°
#     Raw RSSI 5vs2: -30.36 dBm, Filtered RSSI 5vs2: -38.89 dBm (previous measurement was -41.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -79.12 dBm, Filtered RSSI 6vs40: -63.85 dBm (previous measurement was -60.0 dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -131.84 dBm, Filtered RSSI 30vs1: -78.64 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -173.53 dBm, Filtered RSSI 31vs7: -173.53 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 260.849426269 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 598.59 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13457.98, y=70.00, z=-43720.14) with yaw=119.63°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.40, y=70.00, z=-43725.59) with yaw=148.53°
#     Raw RSSI 5vs2: -29.84 dBm, Filtered RSSI 5vs2: -38.81 dBm (previous measurement was None dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -111.84 dBm, Filtered RSSI 6vs40: -69.31 dBm (previous measurement was -63.0 dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -134.28 dBm, Filtered RSSI 30vs1: -79.05 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -125.71 dBm, Filtered RSSI 31vs7: -125.71 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 261.423339843 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 585.33 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13457.07, y=70.00, z=-43720.48) with yaw=122.49°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.08, y=70.00, z=-43727.71) with yaw=161.16°
#     Raw RSSI 5vs2: -32.40 dBm, Filtered RSSI 5vs2: -39.57 dBm (previous measurement was None dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -72.89 dBm, Filtered RSSI 6vs40: -62.81 dBm (previous measurement was -63.0 dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -131.36 dBm, Filtered RSSI 30vs1: -78.56 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 261.950164794 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 546.31 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13455.83, y=70.00, z=-43720.97) with yaw=126.52°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -31.96 dBm, Filtered RSSI 5vs2: -39.49 dBm (previous measurement was None dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -64.80 dBm (previous measurement was -63.0 dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -160.73 dBm, Filtered RSSI 30vs1: -83.46 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 262.609710693 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 615.04 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13454.62, y=70.00, z=-43721.61) with yaw=130.75°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -31.75 dBm, Filtered RSSI 5vs2: -39.46 dBm (previous measurement was None dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.30 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -162.23 dBm, Filtered RSSI 30vs1: -83.70 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 263.170471191 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 350.74 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13454.42, y=70.00, z=-43721.72) with yaw=131.39°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -40.52 dBm, Filtered RSSI 5vs2: -40.92 dBm (previous measurement was None dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -162.64 dBm, Filtered RSSI 30vs1: -83.77 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 263.483184814 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 289.46 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13453.83, y=70.00, z=-43722.09) with yaw=133.80°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -32.65 dBm, Filtered RSSI 5vs2: -39.61 dBm (previous measurement was None dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -164.16 dBm, Filtered RSSI 30vs1: -84.03 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 263.8565979 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 305.59 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13453.69, y=70.00, z=-43722.20) with yaw=134.36°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -32.94 dBm, Filtered RSSI 5vs2: -39.66 dBm (previous measurement was None dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -164.50 dBm, Filtered RSSI 30vs1: -84.08 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 264.109436035 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 289.98 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13453.13, y=70.00, z=-43722.60) with yaw=136.66°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -30.62 dBm, Filtered RSSI 5vs2: -39.27 dBm (previous measurement was None dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -164.90 dBm, Filtered RSSI 30vs1: -84.15 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 264.484008789 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 318.45 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13452.85, y=70.00, z=-43722.81) with yaw=138.16°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -30.00 dBm, Filtered RSSI 5vs2: -39.17 dBm (previous measurement was None dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -164.59 dBm, Filtered RSSI 30vs1: -84.10 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 264.730163574 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 364.84 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13452.45, y=70.00, z=-43723.16) with yaw=140.61°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -120.98 dBm, Filtered RSSI 5vs2: -54.33 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -163.41 dBm, Filtered RSSI 30vs1: -83.90 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 265.106842041 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 362.94 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13451.65, y=70.00, z=-43724.08) with yaw=146.00°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -106.99 dBm, Filtered RSSI 5vs2: -52.00 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -161.93 dBm, Filtered RSSI 30vs1: -83.66 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 265.432189941 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 306.79 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13451.38, y=70.00, z=-43724.42) with yaw=147.93°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -300.00 dBm, Filtered RSSI 5vs2: -84.17 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 6vs40: -133.15 dBm, Filtered RSSI 6vs40: -74.69 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -161.95 dBm, Filtered RSSI 30vs1: -83.66 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 265.68170166 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 293.86 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13450.73, y=70.00, z=-43725.41) with yaw=153.45°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -300.00 dBm, Filtered RSSI 5vs2: -84.17 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 6vs40: -133.15 dBm, Filtered RSSI 6vs40: -74.69 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -163.15 dBm, Filtered RSSI 30vs1: -83.86 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 266.112854003 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 362.90 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13450.38, y=70.00, z=-43726.12) with yaw=157.20°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -300.00 dBm, Filtered RSSI 5vs2: -84.17 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 6vs40: -133.15 dBm, Filtered RSSI 6vs40: -74.69 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -300.00 dBm, Filtered RSSI 30vs1: -106.67 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 266.478088378 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 338.72 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13450.08, y=70.00, z=-43726.80) with yaw=161.08°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -300.00 dBm, Filtered RSSI 5vs2: -84.17 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -300.00 dBm, Filtered RSSI 30vs1: -106.67 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 266.722503662 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 266.81 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13449.70, y=70.00, z=-43728.07) with yaw=167.57°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -300.00 dBm, Filtered RSSI 5vs2: -84.17 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -300.00 dBm, Filtered RSSI 30vs1: -106.67 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 267.096282958 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 268.84 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13449.57, y=70.00, z=-43728.58) with yaw=169.91°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -133.07 dBm, Filtered RSSI 5vs2: -56.34 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -300.00 dBm, Filtered RSSI 30vs1: -106.67 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 267.346405029 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 267.76 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13449.45, y=70.00, z=-43729.55) with yaw=173.84°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -134.39 dBm, Filtered RSSI 5vs2: -56.57 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -300.00 dBm, Filtered RSSI 30vs1: -106.67 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 267.596740722 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 348.05 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13449.43, y=70.00, z=-43730.57) with yaw=175.36°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -137.54 dBm, Filtered RSSI 5vs2: -57.09 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -300.00 dBm, Filtered RSSI 30vs1: -106.67 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 267.97277832 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 271.30 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13449.43, y=70.00, z=-43731.56) with yaw=178.04°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -300.00 dBm, Filtered RSSI 5vs2: -84.17 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -300.00 dBm, Filtered RSSI 30vs1: -106.67 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 268.228607177 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 344.22 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13449.44, y=70.00, z=-43732.59) with yaw=180.31°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -300.00 dBm, Filtered RSSI 5vs2: -84.17 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -300.00 dBm, Filtered RSSI 30vs1: -106.67 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 268.605316162 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 342.88 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13449.48, y=70.00, z=-43733.52) with yaw=183.21°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -300.00 dBm, Filtered RSSI 5vs2: -84.17 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
#     Raw RSSI 30vs1: -300.00 dBm, Filtered RSSI 30vs1: -106.67 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 31vs7: -300.00 dBm, Filtered RSSI 31vs7: -300.00 dBm (previous measurement was 0 dBm) LOS: False, Can BF: False
#     - - - Predicted Topology for original timestamp 268.672698974 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 30->1 (I2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 265.58 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 31vs7
#     Updating Vehicle 1 at dt=1.000s to position (x=-13449.55, y=70.00, z=-43734.40) with yaw=185.26°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13451.13, y=70.00, z=-43727.87) with yaw=162.12°
#     Raw RSSI 5vs2: -300.00 dBm, Filtered RSSI 5vs2: -84.17 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 6vs40: -79.83 dBm, Filtered RSSI 6vs40: -65.80 dBm (previous measurement was None dBm) LOS: False, Can BF: True
# ...
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 406.25 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.30) with yaw=14.90°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.89, y=70.00, z=-43733.91) with yaw=7.42°
#     Raw RSSI 5vs2: -38.35 dBm, Filtered RSSI 5vs2: -47.06 dBm (previous measurement was -49.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.40 dBm, Filtered RSSI 30vs1: -77.73 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.04 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 474.144714355 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 338.77 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.31) with yaw=14.91°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.89, y=70.00, z=-43733.91) with yaw=7.42°
#     Raw RSSI 5vs2: -47.83 dBm, Filtered RSSI 5vs2: -48.80 dBm (previous measurement was None dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.40 dBm, Filtered RSSI 30vs1: -77.73 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.04 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 474.806335449 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 234.52 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.32) with yaw=14.92°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.89, y=70.00, z=-43733.92) with yaw=7.40°
#     Raw RSSI 5vs2: -35.80 dBm, Filtered RSSI 5vs2: -46.97 dBm (previous measurement was -50.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.41 dBm, Filtered RSSI 30vs1: -77.74 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.05 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 475.098602294 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 476.71 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.32) with yaw=14.92°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.88, y=70.00, z=-43733.92) with yaw=7.41°
#     Raw RSSI 5vs2: -38.35 dBm, Filtered RSSI 5vs2: -47.73 dBm (previous measurement was -51.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.41 dBm, Filtered RSSI 30vs1: -77.73 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.05 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 475.469970703 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 306.73 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.32) with yaw=14.91°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.88, y=70.00, z=-43733.91) with yaw=7.41°
#     Raw RSSI 5vs2: -34.04 dBm, Filtered RSSI 5vs2: -47.34 dBm (previous measurement was -51.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.41 dBm, Filtered RSSI 30vs1: -77.73 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.05 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 475.819519042 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 353.78 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.31) with yaw=14.91°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.89, y=70.00, z=-43733.92) with yaw=7.41°
#     Raw RSSI 5vs2: -38.29 dBm, Filtered RSSI 5vs2: -48.05 dBm (previous measurement was -49.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.40 dBm, Filtered RSSI 30vs1: -77.73 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.05 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 476.21786499 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 549.96 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.30) with yaw=14.91°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.89, y=70.00, z=-43733.92) with yaw=7.40°
#     Raw RSSI 5vs2: -35.84 dBm, Filtered RSSI 5vs2: -47.81 dBm (previous measurement was -50.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.40 dBm, Filtered RSSI 30vs1: -77.73 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.05 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 476.712799072 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 376.50 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.31) with yaw=14.91°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.88, y=70.00, z=-43733.91) with yaw=7.43°
#     Raw RSSI 5vs2: -41.95 dBm, Filtered RSSI 5vs2: -48.66 dBm (previous measurement was -49.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.41 dBm, Filtered RSSI 30vs1: -77.73 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.04 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 477.096221923 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 404.35 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.32) with yaw=14.91°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.88, y=70.00, z=-43733.91) with yaw=7.42°
#     Raw RSSI 5vs2: -47.82 dBm, Filtered RSSI 5vs2: -49.30 dBm (previous measurement was -49.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.41 dBm, Filtered RSSI 30vs1: -77.73 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.05 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 477.472869873 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 263.37 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.31) with yaw=14.91°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.88, y=70.00, z=-43733.92) with yaw=7.40°
#     Raw RSSI 5vs2: -41.82 dBm, Filtered RSSI 5vs2: -47.97 dBm (previous measurement was -49.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.40 dBm, Filtered RSSI 30vs1: -77.73 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.05 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 477.665679931 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 424.07 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.32) with yaw=14.92°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.89, y=70.00, z=-43733.90) with yaw=7.42°
#     Raw RSSI 5vs2: -41.74 dBm, Filtered RSSI 5vs2: -47.96 dBm (previous measurement was -49.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.40 dBm, Filtered RSSI 30vs1: -77.73 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.04 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 478.225616455 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 421.20 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.32) with yaw=14.91°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.89, y=70.00, z=-43733.91) with yaw=7.42°
#     Raw RSSI 5vs2: -47.58 dBm, Filtered RSSI 5vs2: -48.76 dBm (previous measurement was -49.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.41 dBm, Filtered RSSI 30vs1: -77.73 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.05 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 478.580596923 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 341.14 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.31) with yaw=14.91°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.88, y=70.00, z=-43733.92) with yaw=7.40°
#     Raw RSSI 5vs2: -42.36 dBm, Filtered RSSI 5vs2: -47.89 dBm (previous measurement was -49.0 dBm) LOS: True, Can BF: True
#     Raw RSSI 6vs40: -300.00 dBm, Filtered RSSI 6vs40: -102.50 dBm (previous measurement was None dBm) LOS: False, Can BF: False
#     Raw RSSI 30vs1: -126.40 dBm, Filtered RSSI 30vs1: -77.73 dBm (previous measurement was 0 dBm) LOS: False, Can BF: True
#     Raw RSSI 31vs7: -60.05 dBm, Filtered RSSI 31vs7: -67.51 dBm (previous measurement was -69.0 dBm) LOS: True, Can BF: True
#     - - - Predicted Topology for original timestamp 478.820587158 plus horizon 1s - - -
#     ->  Predicted Topology_Vehicle2_1: 5->2 (V2V)
#     ->  Predicted Topology_RSU_Vehicle1: 31->7->5->2 (I2V2V)
#
#   - - - - - - - - - - - - - - - - -   Handled in 367.27 ms   - - - - - - - - - - - - - - - - -
#
#
#
#   Received message from ('11.0.0.1', 53742)
#
#   - - - - - - - - - - - - - - - - -  NEW PREDICTION REQUEST  - - - - - - - - - - - - - - - - -
#
#  [WARN] Got no measurement for 30vs1
#     Updating Vehicle 1 at dt=1.000s to position (x=-13508.37, y=70.00, z=-43764.32) with yaw=14.92°
#     Updating Vehicle 3 at dt=1.000s to position (x=-13504.88, y=70.00, z=-43733.91) with yaw=7.42°

# %% [markdown]
# # Utilities

# %% [markdown]
# ### Scene previewer

# %%
scene.preview(resolution=(1000, 1000), show_orientations=True, show_devices=True)

# %% [markdown]
# ### Mobility quick tests

# %%
utils.move_object(ref_obj_id=1, 
                  position=[195.584, 189.436, 0.758495],
                  ref_system="sionna",
                  heading_angle=0, 
                  velocity=5,
                  sionna_structure=struc)

utils.move_object(ref_obj_id=2, 
                  position=[204.080, 188.896, 0.975445], 
                  ref_system="sionna",
                  heading_angle=190, 
                  velocity=2,
                  sionna_structure=struc)

# %%
a1 = -14.9 
a2 = -6.88

a1a = -a1 + 90
a2a = -a2 + 90 

utils.move_object(ref_obj_id=1, 
                  position=[-13490.44, -43708.46, 0.758495],
                  heading_angle=a1a, 
                  velocity=5,
                  sionna_structure=struc)

utils.move_object(ref_obj_id=2, 
                  position=[-13485.85, -43709.28, 0.975445],
                  heading_angle=a2a, 
                  velocity=5,
                  sionna_structure=struc)

# %%
utils.move_object(ref_obj_id=2, 
                  position=[-13484.683, -43709.469, 0.975445],
                  heading_angle=-7-90, 
                  velocity=5,
                  sionna_structure=struc)

# %% [markdown]
# ### Topology computation

# %%
topology = tp.evaluate_best_topology(sionna_structure=struc)
topology

# %% [markdown]
# ### Displacement calculator
# Note: displacement is computed with cars at their default orientation after being imported (facing Ookayama north)

# %%
car_1 = [193.263, 182.911, 0.758495]
car_2 = [213.124, 191.882, 0.874555]

car_1 = scene.get("obj_1").position
car_2 = scene.get("obj_2").position

car_1 = [car_1[0][0], car_1[1][0], car_1[2][0]]
car_2 = [car_2[0][0], car_2[1][0], car_2[2][0]]
print("Car 1 position:", car_1)
print("Car 2 position:", car_2)

# Car 1
ant_1 = [192.904, 182.863, 1.496 + 0.1]
ant_2 = [193.982, 182.884, 0.978 + 0.1]

# Car 2
ant_5 = [212.100, 191.834, 1.746 + 0.20]
ant_6 = [212.693, 191.873, 1.746 + 0.20]
ant_7 = [212.784, 191.845, 1.747 + 0.20]

displacement_1 = np.array(ant_1) - np.array(car_1)
displacement_2 = np.array(ant_2) - np.array(car_1)
displacement_5 = np.array(ant_5) - np.array(car_2)
displacement_6 = np.array(ant_6) - np.array(car_2)
displacement_7 = np.array(ant_7) - np.array(car_2)

print("Displacement Antenna 1:", displacement_1)
print("Displacement Antenna 2:", displacement_2)
print("Displacement Antenna 5:", displacement_5)
print("Displacement Antenna 6:", displacement_6)
print("Displacement Antenna 7:", displacement_7)
